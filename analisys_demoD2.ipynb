# %%
import pandas as pd
import scipy.io as scipy
import matplotlib.pyplot as plt

# %%
mat = scipy.loadmat('datasets\\grupoDados2.mat')

# %%
df = pd.DataFrame(data=mat['grupoTrain'])

# %%
df.describe()
# Out:
#                0           1          2           3           4           5   \
# count  118.000000  118.000000  118.00000  118.000000  118.000000  118.000000
# mean    12.973559    2.316695    2.36000   19.594068   99.711864    2.296695
# std      0.819885    1.130930    0.28885    3.514957   13.777910    0.630807
# min     11.030000    0.740000    1.36000   10.600000   70.000000    0.980000
# 25%     12.370000    1.540000    2.21000   17.500000   88.250000    1.742500
# 50%     13.040000    1.805000    2.35500   19.550000   98.000000    2.310000
# 75%     13.635000    3.030000    2.54000   21.375000  107.000000    2.800000
# max     14.830000    5.650000    3.23000   30.000000  162.000000    3.880000
#
#                6           7           8           9           10          11  \
# count  118.000000  118.000000  118.000000  118.000000  118.000000  118.000000
# mean     2.023983    0.365339    1.578644    4.960847    0.966746    2.577881
# ...

# %%
x = [1,2,3,4]
plt.bar(x, [df[4].sum(), df[5].sum(), df[6].sum(), df[7].sum(),])
# Out:
# <BarContainer object of 4 artists>
